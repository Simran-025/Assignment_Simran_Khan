# %%
# !pip install transformers==4.57.6 datasets==2.21.0 accelerate==0.32.1 sentencepiece==0.2.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 121.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 45.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.1/314.1 kB 32.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 83.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 19.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 42.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 106.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: sentencepiece
#     Found existing installation: sentencepiece 0.2.2
#     Uninstalling sentencepiece-0.2.2:
#       Successfully uninstalled sentencepiece-0.2.2
#   Attempting uninstall: numpy
# ...

# %%
from transformers import pipeline
classifier=pipeline("sentiment-analysis")
text="The storyline was amazing, but the ending was disappointing"
output=classifier(text)
print(output)
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  268MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# [{'label': 'NEGATIVE', 'score': 0.9935680031776428}]

# %%
import pandas as pd
pd.DataFrame(output)
# Out:
#       label     score
# 0  NEGATIVE  0.993568

# %% [markdown]
# **Assignment-2**

# %%
from transformers import pipeline
classifier=pipeline("sentiment-analysis",model="tabularisai/multilingual-sentiment-analysis")
text=["The storyline was amazing, but the ending was disappointing","यह जगह सच में अद्भुत है!"]
output=classifier(text)
print(output)
# Out:
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# [{'label': 'Negative', 'score': 0.8132783770561218}, {'label': 'Very Positive', 'score': 0.7506243586540222}]

# %%
import pandas as pd
pd.DataFrame(output)
# Out:
#                                       generated_text
# 0  write code to sort the array using quicksort a...

# %% [markdown]
# **Assignment-3**

# %%
from transformers import pipeline
generator=pipeline("text-generation",model="Qwen/Qwen2.5-Coder-7B-Instruct")
text="Define AI."
output=generator(text)
print(output)
# Out:
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...
